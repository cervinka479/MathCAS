# %%
import os
import sys
from pathlib import Path

cwd = Path.cwd().resolve()
project_root = next(
    (p for p in [cwd, *cwd.parents] if (p / "main.py").exists() and (p / "src").exists()),
    cwd,
)
os.chdir(project_root)

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"project_root={project_root}")
print(f"cwd={Path.cwd().resolve()}")
# Out:
# project_root=C:\Users\cervinka\cervinka\GitHub\MathCAS
# cwd=C:\Users\cervinka\cervinka\GitHub\MathCAS

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r'datasets/dataset_compressible_flow_60M_training_nstep180.csv')

# Extract data from 50 million to 55 million (assuming row indices)
test_df = df.iloc[50_000_000:55_000_000]

# Save as test dataset
test_df.to_csv('datasets/dataset_compressible_flow_5M_test.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # Load the dataset
# ----> 4 df = pd.read_csv(r'datasets/dataset_compressible_flow_60M_training_nstep180.csv')
#       6 # Extract data from 50 million to 55 million (assuming row indices)
#       7 test_df = df.iloc[50_000_000:55_000_000]
#
# ...

# %%
import csv

csv_path = r'datasets\dataset_compressible_flow_60M_training_nstep180.csv'

with open(csv_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    headers = next(reader)
    print("Headings:", headers)

# %% [markdown]
# ## Create Prediction Dataset

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import pandas as pd
import torch
import numpy as np
from pathlib import Path
from src.evaluation import load_model
from config import load_config

# --- USER INPUTS ---
model_dir = project_root / r"outputs\2025-08-04_22-52-39_dan_750"
test_csv = r"datasets\dataset_compressible_flow_eda_50M_training_nstep180.csv"
output_csv = r"datasets\dataset_compressible_flow_eda_50M_training_nstep180_with_dan_750.csv"

# --- LOAD MODEL ---
config = load_config(model_dir / "config.yaml")
model = load_model(config, model_dir)
model.eval()

chunk_size = 100_000  # Adjust as needed for your memory
predictions = []

for chunk in pd.read_csv(test_csv, chunksize=chunk_size):
    # Prepare input
    inputs = chunk[config.data.in_cols].values
    tensor = torch.tensor(inputs, dtype=torch.float32)
    with torch.no_grad():
        pred_all = model(tensor).detach().cpu().numpy()
    # If model outputs multiple columns, use only the last one (adjust if needed)
    if pred_all.ndim == 2:
        pred = pred_all[:, -1]
    else:
        pred = pred_all[-1]
    predictions.append(pred)

# Concatenate all predictions
all_preds = np.concatenate(predictions, axis=0)

# Save to new CSV
df = pd.read_csv(test_csv)
df["PredShear"] = all_preds
df.to_csv(output_csv, index=False)
print(f"Predictions saved to {output_csv}")
# Out:
# Predictions saved to datasets\dataset_compressible_flow_eda_50M_training_nstep180_with_dan_750.csv

# %%
count = 0
with open(r"datasets\dataset_compressible_flow_eda_50M_training_nstep180_with_dan_1500.csv", "rb") as f:
    for line in f:
        count += 1
print(count)
# Out:
# 50000001

# %% [markdown]
# ## Target Values Analysis

# %%
import pandas as pd

file_path = r"datasets\dataset_compressible_flow_5M_test.csv"
columns = ["ResVort", "ResStrain", "Shear"]

df = pd.read_csv(file_path)

summary = df[columns].agg(["mean", "median", "std", "min", "max", "skew", "kurt"])
print(summary)
# Out:
#          ResVort  ResStrain     Shear
# mean    0.153661   0.532572  1.306815
# median  0.000000   0.432821  1.340973
# std     0.264383   0.448108  0.404586
# min     0.000000   0.000009  0.010807
# max     2.208436   2.572517  2.649451
# skew    2.124124   0.786136 -0.337872
# kurt    4.514600  -0.128803 -0.384844

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme(style="whitegrid")
plt.rcParams.update({'font.size': 12})

df_sample = df[["ResVort", "ResStrain", "Shear"]].sample(n=100000, random_state=42)

# Create a figure with 3 rows of plots
fig = plt.figure(figsize=(12, 12), constrained_layout=True)
gs = fig.add_gridspec(3, 2)

# --- 1. HISTOGRAMS (DISTRIBUTIONS) ---
# Here we observe data shape (skewness and kurtosis)
ax_hist_vort = fig.add_subplot(gs[0, 0])
sns.histplot(data=df_sample, x="ResVort", bins=50, color="purple", kde=True, ax=ax_hist_vort)
ax_hist_vort.set_title("Residual Vorticity Distribution (High Kurtosis)")
ax_hist_vort.set_yscale("log")  # IMPORTANT: Logarithmic Y-axis due to dominant zero values
ax_hist_vort.set_xlabel("Magnitude")
ax_hist_vort.set_ylabel("Count (Log scale)")

ax_hist_shear = fig.add_subplot(gs[0, 1])
# Overlay histograms for Shear and ResStrain with different colors
sns.histplot(data=df_sample, x="Shear", bins=50, color="green", kde=True, ax=ax_hist_shear, alpha=0.6, label="Shear")
sns.histplot(data=df_sample, x="ResStrain", bins=50, color="blue", kde=True, ax=ax_hist_shear, alpha=0.6, label="ResStrain")
ax_hist_shear.set_title("Shear and ResStrain Distributions")
ax_hist_shear.set_xlabel("Magnitude")
ax_hist_shear.set_ylabel("Count")
ax_hist_shear.legend()

# --- 2. SCALE COMPARISON (BOXPLOT) ---
# Here we observe differences in averages and ranges (Scale Hypothesis)
ax_box = fig.add_subplot(gs[1, :])
# Melt the data so variables can be plotted side by side in one chart
df_melted = df_sample.melt(var_name="Variable", value_name="Magnitude")
sns.boxplot(data=df_melted, x="Variable", y="Magnitude", ax=ax_box, palette="Set2")
ax_box.set_title("Comparison of Value Ranges (Scale Hypothesis)")
ax_box.set_ylabel("Magnitude")

# --- 3. CORRELATION (HEATMAP) ---
# Here we see whether the variables are related (physical coupling)
ax_corr = fig.add_subplot(gs[2, :])
# Compute correlation on the full dataset (this is fast)
corr_matrix = df[["ResVort", "ResStrain", "Shear"]].corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, fmt=".2f", ax=ax_corr)
ax_corr.set_title("Pearson Correlation Matrix")

# Save the plot
# plt.savefig("dataset_analysis.png", dpi=300)
plt.show()
# Out:
# C:\Users\cervinka\AppData\Local\Temp\ipykernel_19336\795217420.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_melted, x="Variable", y="Magnitude", ax=ax_box, palette="Set2")

# %% [markdown]
# ## Error Correlation Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from pathlib import Path
from src.evaluation import load_model
from config import load_config

import sys

project_root = Path.cwd()  # Changed from Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# --- USER INPUTS ---
model_dir = project_root / r"outputs\dan_1500"
file_path = project_root / r"datasets\dataset_compressible_flow_5M_test.csv"

# --- 1. LOAD MODEL ---
config = load_config(model_dir / "config.yaml")
model = load_model(config, model_dir)
model.eval()

# --- 2. PREPARE DATA ---
# Load test set (sample for faster analysis)
df_test = pd.read_csv(file_path).sample(n=100000, random_state=42)

# Get column names from config
input_cols = config.data.in_cols
target_cols = config.data.out_cols

# Convert to tensors
X_test = torch.tensor(df_test[input_cols].values, dtype=torch.float32)
y_true = df_test[target_cols].values  # Numpy array for evaluation

# --- 3. PREDICTION ---
with torch.no_grad():
    y_pred_tensor = model(X_test)
    y_pred = y_pred_tensor.cpu().numpy()

# --- 4. CALCULATE ERRORS (RESIDUALS) ---
# Compute absolute error: |True - Pred|
errors = np.abs(y_true - y_pred)
df_errors = pd.DataFrame(errors, columns=[f"Err_{col}" for col in target_cols])

# --- 5. VISUALIZE ERROR CORRELATION ---
# Main interest: Shear Error vs. Vorticity Error

fig, ax = plt.subplots(figsize=(10, 8))

# Use HEXBIN plot (100k points would make scatter unreadable)
# X-axis: Shear Error
# Y-axis: Vorticity Error
# Color: Number of points in each hexagon (log scale)
hb = ax.hexbin(x=df_errors[f"Err_{target_cols[-1]}"],  # Last column is usually Shear
               y=df_errors[f"Err_{target_cols[0]}"],   # First column is usually ResVort
               gridsize=50,
               cmap='inferno',
               bins='log',  # Log scale for colors
               mincnt=1)

cb = fig.colorbar(hb, ax=ax, label='Number of samples (log)')
ax.set_xlabel(f'Absolute error: {target_cols[-1]}')
ax.set_ylabel(f'Absolute error: {target_cols[0]}')
ax.set_title('Prediction error correlation (Error Analysis)')

# Add trend line (error regression) to see the trend
sns.regplot(x=df_errors[f"Err_{target_cols[-1]}"],
            y=df_errors[f"Err_{target_cols[0]}"],
            scatter=False, color="cyan", ax=ax, line_kws={"linestyle": "--"})

# Calculate error correlation
corr_err = df_errors[f"Err_{target_cols[-1]}"].corr(df_errors[f"Err_{target_cols[0]}"])
ax.text(0.05, 0.95, f'Correlation of Errors: r = {corr_err:.3f}',
        transform=ax.transAxes, color='white', fontsize=12, fontweight='bold',
        bbox=dict(facecolor='black', alpha=0.5))

plt.show()

# --- 6. PRINT STATISTICS ---
print("Error correlation matrix:")
print(df_errors.corr())
print("\nMean errors:")
print(df_errors.mean())
print("\nMedian errors:")
print(df_errors.median())
# Out:
# Error correlation matrix:
#                Err_ResVort  Err_ResStrain  Err_Shear
# Err_ResVort       1.000000       0.565526   0.760225
# Err_ResStrain     0.565526       1.000000   0.512943
# Err_Shear         0.760225       0.512943   1.000000
#
# Mean errors:
# Err_ResVort      0.002141
# Err_ResStrain    0.003293
# Err_Shear        0.002574
# dtype: float64
#
# Median errors:
# Err_ResVort      0.000377
# Err_ResStrain    0.002298
# Err_Shear        0.001905
# dtype: float64
